# %%
# Import

import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read CSV

df = pd.read_csv('data.csv')
df
# Out:
#     index  brain_weight  body_weight
# 0       1         3.385        44.50
# 1       2         0.480        15.50
# 2       3         1.350         8.10
# 3       4       465.000       423.00
# 4       5        36.330       119.50
# 5       6        27.660       115.00
# 6       7        14.830        98.20
# 7       8         1.040         5.50
# 8       9         4.190        58.00
# 9      10         0.425         6.40
# 10     11         0.101         4.00
# 11     12         0.920         5.70
# 12     13         1.000         6.60
# 13     14         0.005         0.14
# 14     15         0.060         1.00
# 15     16         3.500        10.80
# 16     17         2.000        12.30
# 17     18         1.700         6.30
# 18     19      2547.000      4603.00
# 19     20         0.023         0.30
# 20     21       187.100       419.00
# 21     22       521.000       655.00
# 22     23         0.785         3.50
# 23     24        10.000       115.00
# 24     25         3.300        25.60
# 25     26         0.200         5.00
# 26     27         1.410        17.50
# 27     28       529.000       680.00
# 28     29       207.000       406.00
# 29     30        85.000       325.00
# ..    ...           ...          ...
# 32     33      6654.000      5712.00
# 33     34         3.500         3.90
# 34     35         6.800       179.00
# 35     36        35.000        56.00
# 36     37         4.050        17.00
# 37     38         0.120         1.00
# 38     39         0.023         0.40
# 39     40         0.010         0.25
# 40     41         1.400        12.50
# 41     42       250.000       490.00
# 42     43         2.500        12.10
# 43     44        55.500       175.00
# 44     45       100.000       157.00
# 45     46        52.160       440.00
# 46     47        10.550       179.50
# 47     48         0.550         2.40
# 48     49        60.000        81.00
# 49     50         3.600        21.00
# 50     51         4.288        39.20
# 51     52         0.280         1.90
# 52     53         0.075         1.20
# 53     54         0.122         3.00
# 54     55         0.048         0.33
# 55     56       192.000       180.00
# 56     57         3.000        25.00
# 57     58       160.000       169.00
# 58     59         0.900         2.60
# 59     60         1.620        11.40
# 60     61         0.104         2.50
# 61     62         4.235        50.40
#
# [62 rows x 3 columns]

# %%
# Data Types

df.dtypes
# Out:
# index             int64
# brain_weight    float64
# body_weight     float64
# dtype: object

# %%
# X = Body Weight
# Y = Brain Weight

# Sort by X

df = df.sort_values(by='body_weight')
df
# Out:
#     index  brain_weight  body_weight
# 13     14         0.005         0.14
# 39     40         0.010         0.25
# 19     20         0.023         0.30
# 54     55         0.048         0.33
# 38     39         0.023         0.40
# 14     15         0.060         1.00
# 37     38         0.120         1.00
# 52     53         0.075         1.20
# 51     52         0.280         1.90
# 47     48         0.550         2.40
# 60     61         0.104         2.50
# 58     59         0.900         2.60
# 53     54         0.122         3.00
# 22     23         0.785         3.50
# 33     34         3.500         3.90
# 10     11         0.101         4.00
# 25     26         0.200         5.00
# 7       8         1.040         5.50
# 11     12         0.920         5.70
# 17     18         1.700         6.30
# 9      10         0.425         6.40
# 12     13         1.000         6.60
# 2       3         1.350         8.10
# 15     16         3.500        10.80
# 59     60         1.620        11.40
# 42     43         2.500        12.10
# 30     31         0.750        12.30
# 16     17         2.000        12.30
# 40     41         1.400        12.50
# 1       2         0.480        15.50
# ..    ...           ...          ...
# 49     50         3.600        21.00
# 56     57         3.000        25.00
# 24     25         3.300        25.60
# 50     51         4.288        39.20
# 0       1         3.385        44.50
# 61     62         4.235        50.40
# 35     36        35.000        56.00
# 8       9         4.190        58.00
# 48     49        60.000        81.00
# 6       7        14.830        98.20
# 5       6        27.660       115.00
# 23     24        10.000       115.00
# 4       5        36.330       119.50
# 44     45       100.000       157.00
# 57     58       160.000       169.00
# 43     44        55.500       175.00
# 34     35         6.800       179.00
# 46     47        10.550       179.50
# 55     56       192.000       180.00
# 29     30        85.000       325.00
# 28     29       207.000       406.00
# 20     21       187.100       419.00
# 3       4       465.000       423.00
# 45     46        52.160       440.00
# 41     42       250.000       490.00
# 21     22       521.000       655.00
# 27     28       529.000       680.00
# 31     32        62.000      1320.00
# 18     19      2547.000      4603.00
# 32     33      6654.000      5712.00
#
# [62 rows x 3 columns]

# %%
# Draw Chart

df.groupby('body_weight').brain_weight.mean().plot.line(linestyle='--', marker='o')
plt.show()

# %%
# Filter

df = df[df.body_weight < 50]
df
# Out:
#     index  brain_weight  body_weight
# 13     14         0.005         0.14
# 39     40         0.010         0.25
# 19     20         0.023         0.30
# 54     55         0.048         0.33
# 38     39         0.023         0.40
# 14     15         0.060         1.00
# 37     38         0.120         1.00
# 52     53         0.075         1.20
# 51     52         0.280         1.90
# 47     48         0.550         2.40
# 60     61         0.104         2.50
# 58     59         0.900         2.60
# 53     54         0.122         3.00
# 22     23         0.785         3.50
# 33     34         3.500         3.90
# 10     11         0.101         4.00
# 25     26         0.200         5.00
# 7       8         1.040         5.50
# 11     12         0.920         5.70
# 17     18         1.700         6.30
# 9      10         0.425         6.40
# 12     13         1.000         6.60
# 2       3         1.350         8.10
# 15     16         3.500        10.80
# 59     60         1.620        11.40
# 42     43         2.500        12.10
# 30     31         0.750        12.30
# 16     17         2.000        12.30
# 40     41         1.400        12.50
# 1       2         0.480        15.50
# 36     37         4.050        17.00
# 26     27         1.410        17.50
# 49     50         3.600        21.00
# 56     57         3.000        25.00
# 24     25         3.300        25.60
# 50     51         4.288        39.20
# 0       1         3.385        44.50

# %%
# Draw Chart

df.groupby('body_weight').brain_weight.mean().plot.line(linestyle='--', marker='o')
plt.show()

# %%
# Linear Regression

# Data set

def normalize(x):
    max_x = max(x)
    min_x = min(x)
    return (x - min_x) / (max_x - min_x)

x = normalize(df.body_weight).tolist()
y = normalize(df.brain_weight).tolist()

# Linear Model

w = tf.Variable(tf.truncated_normal([1], stddev=0.1))
b = tf.Variable(tf.truncated_normal([1], stddev=0.1))
y_ = w * x + b

# Loss Function

loss = tf.reduce_mean(tf.square(y - y_))

# Gradient Descent Optimization

learning_rate = 0.3
optimizer = tf.train.GradientDescentOptimizer(learning_rate)

# Initialize

session = tf.InteractiveSession()
tf.global_variables_initializer().run()

# Training

def draw(index):
    print(index, session.run(w), session.run(b))
    plt.plot(x, y, '--o')
    plt.plot(x, session.run(y_), '--o')
    plt.show()

draw(0)

for i in range(100):
    optimizer.minimize(loss).run()
    draw(i + 1)
# Out:
# 0 [-0.00398465] [-0.01076098]
# 1 [ 0.07006068] [ 0.17959489]
# 2 [ 0.11581612] [ 0.24643829]
# 3 [ 0.15046792] [ 0.26742947]
# 4 [ 0.18043184] [ 0.27147424]
# 5 [ 0.20811367] [ 0.26932916]
# 6 [ 0.23442587] [ 0.26499471]
# 7 [ 0.25972447] [ 0.25995654]
# 8 [ 0.28415787] [ 0.25476417]
# 9 [ 0.30779666] [ 0.24961875]
# 10 [ 0.33068201] [ 0.24459192]
# 11 [ 0.35284361] [ 0.23970716]
# 12 [ 0.3743065] [ 0.23497011]
# 13 [ 0.39509347] [ 0.23037988]
# 14 [ 0.41522613] [ 0.22593327]
# 15 [ 0.43472517] [ 0.22162628]
# 16 [ 0.45361057] [ 0.21745472]
# 17 [ 0.47190166] [ 0.21341439]
# 18 [ 0.48961714] [ 0.20950118]
# 19 [ 0.50677514] [ 0.2057111]
# 20 [ 0.52339321] [ 0.2020403]
# 21 [ 0.53948832] [ 0.19848502]
# 22 [ 0.55507696] [ 0.19504161]
# 23 [ 0.57017499] [ 0.19170655]
# 24 [ 0.58479792] [ 0.18847646]
# 25 [ 0.5989607] [ 0.185348]
# 26 [ 0.61267781] [ 0.182318]
# 27 [ 0.62596327] [ 0.17938335]
# 28 [ 0.6388306] [ 0.17654105]
# 29 [ 0.65129304] [ 0.17378819]
# 30 [ 0.66336328] [ 0.17112195]
# 31 [ 0.67505372] [ 0.16853963]
# 32 [ 0.68637627] [ 0.16603857]
# 33 [ 0.69734251] [ 0.16361621]
# 34 [ 0.70796365] [ 0.16127008]
# 35 [ 0.71825057] [ 0.15899777]
# 36 [ 0.72821379] [ 0.15679698]
# 37 [ 0.73786342] [ 0.15466544]
# 38 [ 0.74720943] [ 0.15260097]
# 39 [ 0.75626135] [ 0.15060148]
# 40 [ 0.76502842] [ 0.14866491]
# 41 [ 0.77351958] [ 0.14678927]
# 42 [ 0.78174353] [ 0.14497267]
# 43 [ 0.78970867] [ 0.14321321]
# 44 [ 0.79742318] [ 0.14150915]
# 45 [ 0.80489492] [ 0.13985869]
# 46 [ 0.81213152] [ 0.13826017]
# 47 [ 0.81914037] [ 0.13671197]
# 48 [ 0.82592869] [ 0.13521248]
# 49 [ 0.83250338] [ 0.13376018]
# 50 [ 0.83887118] [ 0.13235359]
# 51 [ 0.84503859] [ 0.13099125]
# 52 [ 0.85101193] [ 0.12967178]
# 53 [ 0.85679728] [ 0.12839384]
# 54 [ 0.86240059] [ 0.12715612]
# 55 [ 0.86782753] [ 0.12595734]
# 56 [ 0.87308371] [ 0.12479629]
# 57 [ 0.87817448] [ 0.12367178]
# 58 [ 0.8831051] [ 0.12258265]
# 59 [ 0.8878805] [ 0.12152779]
# 60 [ 0.89250565] [ 0.12050613]
# 61 [ 0.89698523] [ 0.11951663]
# 62 [ 0.90132385] [ 0.11855825]
# 63 [ 0.90552598] [ 0.11763004]
# 64 [ 0.90959585] [ 0.11673104]
# 65 [ 0.91353762] [ 0.11586033]
# 66 [ 0.91735536] [ 0.11501702]
# 67 [ 0.92105299] [ 0.11420024]
# 68 [ 0.92463422] [ 0.11340917]
# 69 [ 0.92810279] [ 0.112643]
# 70 [ 0.93146217] [ 0.11190093]
# 71 [ 0.93471587] [ 0.11118221]
# 72 [ 0.93786716] [ 0.11048611]
# 73 [ 0.94091928] [ 0.10981192]
# 74 [ 0.94387537] [ 0.10915896]
# 75 [ 0.94673842] [ 0.10852652]
# 76 [ 0.94951141] [ 0.10791399]
# 77 [ 0.95219713] [ 0.10732074]
# 78 [ 0.95479834] [ 0.10674616]
# 79 [ 0.95731765] [ 0.10618965]
# 80 [ 0.95975769] [ 0.10565066]
# 81 [ 0.96212095] [ 0.10512864]
# 82 [ 0.96440983] [ 0.10462303]
# 83 [ 0.9666267] [ 0.10413335]
# 84 [ 0.96877378] [ 0.10365906]
# 85 [ 0.97085333] [ 0.10319972]
# 86 [ 0.97286743] [ 0.10275482]
# 87 [ 0.97481817] [ 0.10232393]
# 88 [ 0.97670752] [ 0.10190658]
# 89 [ 0.97853738] [ 0.10150237]
# 90 [ 0.98030967] [ 0.10111088]
# 91 [ 0.98202616] [ 0.10073172]
# 92 [ 0.98368865] [ 0.10036449]
# 93 [ 0.98529881] [ 0.10000882]
# 94 [ 0.98685831] [ 0.09966434]
# 95 [ 0.98836875] [ 0.09933069]
# 96 [ 0.98983169] [ 0.09900755]
# 97 [ 0.99124855] [ 0.09869457]
# 98 [ 0.99262083] [ 0.09839144]
# 99 [ 0.99394995] [ 0.09809785]
# 100 [ 0.99523723] [ 0.0978135]
