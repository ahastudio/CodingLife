# %% [markdown]
# # 동물보호관리시스템 유기동물 조회 서비스
#
# <https://www.data.go.kr/dataset/15001096/openapi.do>

# %% [markdown]
# 터미널 또는 Git Bash에서 다음을 입력해 API 키를 사용합니다.
#
# ```bash
# # 환경변수 설정. 발급 받은 키로 변경해 주세요.
# export ANIMAL_API_KEY=abcdefghijklm%2FvSfZeu4FoGpl2eGP%2FzlR5eGh%2F9M8jbOv4HPFZI%2BM7ckZstS8OzkMKHNBkpAtdZX6T8VoRl4Q%3D%3D
#
# # Jupyter Notebook 실행
# jupyter notebook
# ```

# %%
# 환경 변수에서 API 키 가져오기

import os
from urllib.parse import unquote

API_KEY = unquote(os.environ['ANIMAL_API_KEY'])

print(API_KEY)
# Out:
# abcdefghijklm/vSfZeu4FoGpl2eGP/zlR5eGh/9M8jbOv4HPFZI+M7ckZstS8OzkMKHNBkpAtdZX6T8VoRl4Q==

# %% [markdown]
# ## requests
#
# <https://2.python-requests.org/>

# %%
# requests 사용

import requests

requests.__version__
# Out:
# '2.22.0'

# %% [markdown]
# ## 동물보호관리시스템 유기동물 조회 서비스 API 사용
#
# API는 Base URL과 `?` 뒤에 `key=value` 형태로 붙는 (연속일 경우 `&` 삽입)
# Query Parameters로 구성되어 있습니다.
#
# Base URL: `http://openapi.animal.go.kr:80/openapi/service/rest/abandonmentPublicSrvc`
#
# Query Parameters:
#
# - `serviceKey`: API 키
# - `bgnde`: 유기날짜 (검색 시작일) (YYYYMMDD)
# - `endde`: 유기날짜 (검색 종료일) (YYYYMMDD)
# - `numOfRows`: 페이지당 보여줄 개수
#
# 이번에는 넉넉히 20개를 얻어오겠습니다.

# %%
# 동물보호관리시스템 유기동물 조회 서비스 API

url = 'http://openapi.animal.go.kr/openapi/service/rest/abandonmentPublicSrvc/abandonmentPublic'

payload = {
    'serviceKey': API_KEY,
    'bgnde': '20190901',
    'endde': '20190930',
    'numOfRows': 20,
}

response = requests.get(url, params=payload)

print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ## ElementTree로 XML 데이터 파싱
#
# <https://docs.python.org/3/library/xml.etree.elementtree.html>

# %%
import xml.etree.ElementTree as ET

# XML 데이터 파싱

root = ET.fromstring(response.text)

# item 목록에 있는 kindCd와 specialMark 항목 출력

for item in root.iter('item'):
    kind = item.find('kindCd').text
    description = item.find('specialMark').text
    print(f'{kind} | {description}')
# Out:
# [개] 믹스견 | 칩X, 쫑긋한 귀, 윤기나는 털, 우아한 분위기, 사람을 좋아하고 사랑스러움
# [개] 믹스견 | 칩X, 가을 햇살처럼 밝은아이, 처진귀,동그란눈 까맣고 매끈한 코,짧은 다리
# [개] 믹스견 | 흰팩에 꼬리가 길고 꼬리털이 복실복실함
# [개] 믹스견 | 흰색, 온순
# [개] 시츄 | 갈흰색, 온순, 칩있음(410160020123816)
# [개] 믹스견 | 갈색, 경계심이 심함, 들개
# [개] 믹스견 | 흰색, 사나움, 들개
# [개] 말티즈 | 순함. 사람잘따름,연두색 목죽착용 중성화됨
# [고양이] 한국 고양이 | 순함, 2마리가치 구조. 기운없음
# [고양이] 한국 고양이 | 순함. 기운없음. 2마가치구조 눈꼽많이낌,
# [개] 푸들 | 단미 안 함  복벽 잠복 고환
# [개] 그레이트 피레니즈 | 예민함,겁많음
# [개] 말티즈 | 머리 위,귀,꼬리 분홍색염색,순함
# [고양이] 한국 고양이 | .
# [고양이] 한국 고양이 | 수영 2-162, 기력매우저하
# [개] 치와와 | 수영 1-110, 미용됨
# [고양이] 고양이 | 불량(후구장애), 연제구 2-170
# [개] 믹스견 | 겁이많지만, 사람을 잘 따름
# [고양이] 한국 고양이 |
# [개] 믹스견 |

# %% [markdown]
# ## 컬럼 목록 얻기
#
# ElementTree는 Iterator를 사용합니다.
#
# `next` 함수를 사용하면 `for`를 쓰지 않고도 직접 값을 얻을 수 있습니다.
#
# Iterator에 대한 파이썬 위키의 설명: <https://wiki.python.org/moin/Iterator>

# %%
# 첫번째 item을 얻습니다.

item = next(root.iter('item'))

item
# Out:
# <Element 'item' at 0x10aed8710>

# %%
# item 바로 아래에 뭐가 있을까?

list(item)
# Out:
# [<Element 'age' at 0x10aed87d0>,
#  <Element 'careAddr' at 0x10aed8830>,
#  <Element 'careNm' at 0x10aed8890>,
#  <Element 'careTel' at 0x10aed8950>,
#  <Element 'chargeNm' at 0x10aed89b0>,
#  <Element 'colorCd' at 0x10aed8a70>,
#  <Element 'desertionNo' at 0x10aed8b30>,
#  <Element 'filename' at 0x10aed8b90>,
#  <Element 'happenDt' at 0x10aed8bf0>,
#  <Element 'happenPlace' at 0x10aed8c50>,
#  <Element 'kindCd' at 0x10aed8d10>,
#  <Element 'neuterYn' at 0x10aed8d70>,
#  <Element 'noticeEdt' at 0x10aed8dd0>,
#  <Element 'noticeNo' at 0x10aed8e30>,
#  <Element 'noticeSdt' at 0x10aed8e90>,
#  <Element 'officetel' at 0x10aed8ef0>,
#  <Element 'orgNm' at 0x10aed8f50>,
#  <Element 'popfile' at 0x10aed8fb0>,
#  <Element 'processState' at 0x10af36050>,
#  <Element 'sexCd' at 0x10af36110>,
#  <Element 'specialMark' at 0x10af36170>,
#  <Element 'weight' at 0x10af361d0>]

# %%
# 컬럼 목록 준비
columns = []

# Accumulation
for child in list(item):
    columns.append(child.tag)

# 컬럼 목록 확인
print(columns)
# Out:
# ['age', 'careAddr', 'careNm', 'careTel', 'chargeNm', 'colorCd', 'desertionNo', 'filename', 'happenDt', 'happenPlace', 'kindCd', 'neuterYn', 'noticeEdt', 'noticeNo', 'noticeSdt', 'officetel', 'orgNm', 'popfile', 'processState', 'sexCd', 'specialMark', 'weight']

# %% [markdown]
# ## XML 데이터를 Pandas로 변환
#
# <https://pandas.pydata.org/>

# %%
# pandas 사용

import pandas as pd

pd.__version__
# Out:
# '0.24.2'

# %%
# XML 데이터를 dictionary의 list로 만들기

rows = []

for item in root.iter('item'):
    row = {}
    for child in list(item):
        row[child.tag] = child.text
    rows.append(row)

print('갯수:', len(rows))
print()
print(rows[0])
# Out:
# 갯수: 20
#
# {'age': '2018(년생)', 'careAddr': '경상남도 창원시 진해구 웅천로 218 (성내동, 농업기술센터) 205번지 ', 'careNm': '진해유기동물보호소', 'careTel': '055-225-5483', 'chargeNm': '진해구', 'colorCd': '크림', 'desertionNo': '448532201900770', 'filename': 'http://www.animal.go.kr/files/shelter/2019/09/201909191009374_s.jpg', 'happenDt': '20190919', 'happenPlace': '진해구 웅천로 156', 'kindCd': '[개] 믹스견', 'neuterYn': 'N', 'noticeEdt': '20190930', 'noticeNo': '경남-창원3-2019-00439', 'noticeSdt': '20190919', 'officetel': '055-225-5483', 'orgNm': '경상남도 창원시 진해구', 'popfile': 'http://www.animal.go.kr/files/shelter/2019/09/201909191009374.jpg', 'processState': '보호중', 'sexCd': 'F', 'specialMark': '칩X, 쫑긋한 귀, 윤기나는 털, 우아한 분위기, 사람을 좋아하고 사랑스러움', 'weight': '3.5(Kg)'}

# %%
# DataFrame으로 만들기

df = pd.DataFrame(rows, columns=columns)

df
# Out:
#          age                                   careAddr       careNm  \
# 0   2018(년생)  경상남도 창원시 진해구 웅천로 218 (성내동, 농업기술센터) 205번지     진해유기동물보호소
# 1   2018(년생)  경상남도 창원시 진해구 웅천로 218 (성내동, 농업기술센터) 205번지     진해유기동물보호소
# 2   2018(년생)           전라북도 장수군 장수읍 군청길 16 (장수읍) 문 동물병원      문 동물병원
# 3   2018(년생)         강원도 춘천시 신샘밭로 213 (신동) 신동 1206-13번지   춘천시 동물보호센터
# 4   2013(년생)         강원도 춘천시 신샘밭로 213 (신동) 신동 1206-13번지   춘천시 동물보호센터
# 5   2018(년생)         강원도 춘천시 신샘밭로 213 (신동) 신동 1206-13번지   춘천시 동물보호센터
# 6   2017(년생)         강원도 춘천시 신샘밭로 213 (신동) 신동 1206-13번지   춘천시 동물보호센터
# 7   2019(년생)                      경기도 부천시 오정구 원종동 229-8   24시아이동물메디컬
# 8   2019(년생)                      경기도 부천시 오정구 원종동 229-8   24시아이동물메디컬
# 9   2019(년생)                      경기도 부천시 오정구 원종동 229-8   24시아이동물메디컬
# 10  2013(년생)                  울산광역시 남구 북부순환도로 40 (무거동)        남산동물병원
# 11  2013(년생)                        인천광역시 서구 가정동 517-32       가정동물병원
# 12  2016(년생)                        인천광역시 서구 가정동 517-32       가정동물병원
# 13  2019(년생)                  대구광역시 서구 국채보상로 176 (중리동)   대구시수의사회(더난)
# 14  2019(년생)              부산광역시 해운대구 송정2로13번길 46 (송정동)        누리동물병원
# 15  2012(년생)              부산광역시 해운대구 송정2로13번길 46 (송정동)        누리동물병원
# 16  2019(년생)                   부산광역시 연제구 온천천남로 4 (연산동)        청조동물병원
# 17  2017(년생)     경상북도 울릉군 울릉읍 간령길 83-18 (울릉읍) 울릉군농업기술센터    울릉군농업기술센터
# 18  2019(년생)                    경상북도 경주시 금성로 385 (성건동)        가나동물병원
# 19  2017(년생)                    경상북도 경주시 금성로 385 (성건동)        가나동물병원
#
#           careTel chargeNm colorCd      desertionNo  \
# 0    055-225-5483      진해구      크림  448532201900770
# 1    055-225-5483      진해구      크림  448532201900769
# 2   010-8876-3475      장수군      흰색  445475201900136
# 3    033-250-4773      심장수      흰색  442418201900569
# 4    033-250-4773      심장수     갈흰색  442418201900568
# 5    033-250-4773      심장수      갈색  442418201900567
# 6    033-250-4773      심장수      흰색  442418201900566
# 7    032-677-5262      NaN       흰  441386201901122
# 8    032-677-5262      NaN      검정  441386201901121
# 9    032-677-5262      NaN      검정  441386201901120
# 10   052-224-8275      방효빈      흰색  431370201901042
# 11   032-575-0833      장채현      흰색  428356201901272
# 12   032-575-0833      장채현      흰색  428356201901271
# 13   053-552-0075      석주연      삼색  427343201900826
# 14   051-701-7599      허은진    검정흰색  426338201900340
# 15   051-701-7599      허은진    갈색흰색  426338201900339
# 16   051-503-0688      장슬기     검정색  426337201900479
# 17   054-790-6467      박희만     검은색  447526201900134
# 18  010-2230-6303      경주시   블랙화이트  447505201900982
# 19  010-2230-6303      경주시     화이트  447505201900981
#
#                                              filename  happenDt  \
# 0   http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 1   http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 2   http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 3   http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 4   http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 5   http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 6   http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 7   http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 8   http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 9   http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 10  http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 11  http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 12  http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 13  http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 14  http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 15  http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 16  http://www.animal.go.kr/files/shelter/2019/09/...  20190919
# 17  http://www.animal.go.kr/files/shelter/2019/09/...  20190918
# 18  http://www.animal.go.kr/files/shelter/2019/09/...  20190918
# 19  http://www.animal.go.kr/files/shelter/2019/09/...  20190918
#
#                happenPlace  ... noticeEdt           noticeNo noticeSdt  \
# 0              진해구 웅천로 156  ...  20190930  경남-창원3-2019-00439  20190919
# 1              진해구 웅천로 156  ...  20190930  경남-창원3-2019-00438  20190919
# 2                 장계면 소비재로  ...  20191007   전북-장수-2019-00186  20190919
# 3   송암동 비발디파크모텔앞(서부지구대 인계)  ...  20190930   강원-춘천-2019-00493  20190919
# 4               후평동 116-16  ...  20190930   강원-춘천-2019-00492  20190919
# 5               후평동 244-30  ...  20190930   강원-춘천-2019-00491  20190919
# 6               후평동 244-30  ...  20190930   강원-춘천-2019-00490  20190919
# 7          심곡도 403-19 5층계단  ...  20190930   경기-부천-2019-00870  20190919
# 8                     오정구청  ...  20190930   경기-부천-2019-00869  20190919
# 9                     오정구청  ...  20190930   경기-부천-2019-00868  20190919
# 10               무거동 울산대학교  ...  20190929   울산-남구-2019-00723  20190919
# 11              왕길동 이수철강 뒤  ...  20190930   인천-서구-2019-00954  20190919
# 12               가좌동 148-3  ...  20190930   인천-서구-2019-00953  20190919
# 13              평리동 1092-2  ...  20190929   대구-서구-2019-00547  20190919
# 14          부산시 수영구 감포로 18  ...  20190930   부산-수영-2019-00275  20190919
# 15     부산시 수영구 망미번영로70번길 7  ...  20190930   부산-수영-2019-00274  20190919
# 16          중앙대로 1150번길 51  ...  20190930   부산-연제-2019-00356  20190919
# 17          서면 태하령길 1036-7  ...  20190930   경북-울릉-2019-00024  20190919
# 18                  신라고등학교  ...  20190930   경북-경주-2019-00974  20190919
# 19               강동면 모서2리   ...  20190930   경북-경주-2019-00973  20190919
#
#        officetel         orgNm  \
# 0   055-225-5483  경상남도 창원시 진해구
# 1   055-225-5483  경상남도 창원시 진해구
# 2   063-350-2416      전라북도 장수군
# 3   033-250-3790       강원도 춘천시
# 4   033-250-3790       강원도 춘천시
# 5   033-250-3790       강원도 춘천시
# 6   033-250-3790       강원도 춘천시
# 7   032-625-2808       경기도 부천시
# 8   032-625-2808       경기도 부천시
# 9   032-625-2808       경기도 부천시
# 10  052-226-5663      울산광역시 남구
# 11  032-560-4456      인천광역시 서구
# 12  032-560-4456      인천광역시 서구
# 13  053-663-2644      대구광역시 서구
# 14  051-610-4504     부산광역시 수영구
# 15  051-610-4504     부산광역시 수영구
# 16  051-665-4482     부산광역시 연제구
# 17  054-790-6283      경상북도 울릉군
# 18  054-779-6303      경상북도 경주시
# 19  054-779-6303      경상북도 경주시
#
#                                               popfile processState sexCd  \
# 0   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 1   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 2   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 3   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 4   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 5   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 6   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 7   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 8   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     Q
# 9   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     Q
# 10  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 11  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 12  http://www.animal.go.kr/files/shelter/2019/09/...       종료(반환)     F
# 13  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 14  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 15  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 16  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 17  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 18  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 19  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
#
#                                    specialMark    weight
# 0   칩X, 쫑긋한 귀, 윤기나는 털, 우아한 분위기, 사람을 좋아하고 사랑스러움   3.5(Kg)
# 1   칩X, 가을 햇살처럼 밝은아이, 처진귀,동그란눈 까맣고 매끈한 코,짧은 다리   4.9(Kg)
# 2                        흰팩에 꼬리가 길고 꼬리털이 복실복실함    15(Kg)
# 3                                       흰색, 온순     4(Kg)
# 4                갈흰색, 온순, 칩있음(410160020123816)     4(Kg)
# 5                              갈색, 경계심이 심함, 들개    10(Kg)
# 6                                  흰색, 사나움, 들개    15(Kg)
# 7                      순함. 사람잘따름,연두색 목죽착용 중성화됨     3(Kg)
# 8                           순함, 2마리가치 구조. 기운없음   0.5(Kg)
# 9                      순함. 기운없음. 2마가치구조 눈꼽많이낌,   0.5(Kg)
# 10                            단미 안 함  복벽 잠복 고환  4.43(Kg)
# 11                                     예민함,겁많음    30(Kg)
# 12                          머리 위,귀,꼬리 분홍색염색,순함   3.4(Kg)
# 13                                           .  0.15(Kg)
# 14                            수영 2-162, 기력매우저하   0.5(Kg)
# 15                               수영 1-110, 미용됨   2.7(Kg)
# 16                         불량(후구장애), 연제구 2-170   1.3(Kg)
# 17                             겁이많지만, 사람을 잘 따름   3.5(Kg)
# 18                                              0.24(Kg)
# 19                                                25(Kg)
#
# [20 rows x 22 columns]

# %%
data = df['age'].value_counts()

pd.DataFrame(data)
# Out:
#           age
# 2019(년생)    7
# 2018(년생)    5
# 2013(년생)    3
# 2017(년생)    3
# 2016(년생)    1
# 2012(년생)    1

# %%
data = df['kindCd'].value_counts()

pd.DataFrame(data)
# Out:
#                kindCd
# [개] 믹스견             8
# [고양이] 한국 고양이        5
# [개] 말티즈             2
# [개] 그레이트 피레니즈       1
# [고양이] 고양이           1
# [개] 시츄              1
# [개] 푸들              1
# [개] 치와와             1
